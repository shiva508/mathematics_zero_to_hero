# %% [markdown]
# #

# %%
from sympy import Symbol, cos

# %%
x = Symbol('x')
e = 1/cos(x)
series = e.series(x, 0, 10)
print(series)
# Out:
# 1 + x**2/2 + 5*x**4/24 + 61*x**6/720 + 277*x**8/8064 + O(x**10)
