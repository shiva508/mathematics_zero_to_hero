# %% [markdown]
# # Functions

# %%
def hello(input_name :str = "World"):
    print(f"Hello {input_name}")
name = input("What is your name? ")

hello()
hello(name)
# Out:
# Hello World
# Hello Shiva

# %% [markdown]
# # Function  with return

# %%
def square_of_number(input_number :int):
    return input_number * input_number
print(square_of_number(5))
# Out:
# 25
