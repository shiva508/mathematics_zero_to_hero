# %% [markdown]
# # Variables

# %%
input_one = int(input("Enter first input"))
input_two = int(input("Enter second input"))
print(input_two + input_one)
# Out:
# 916

# %% [markdown]
# # float

# %%
input_one = float(input("Enter first input"))
input_two = float(input("Enter second input"))
print(input_two + input_one)
# Out:
# 1016.0

# %% [markdown]
# # round()

# %%
input_one = round(1.954454, 6)
print(input_one)
# Out:
# 1.954454

# %% [markdown]
# # formatting

# %%
x = 999
y = 1
z = x + y
print(f"{z:,}")
# Out:
# 1,000

# %%
input_one = 2
input_two = 3
#result = round(input_one/input_two, 2)
result = input_one/input_two
print(f"{result:.3f}")
# Out:
# 0.667
